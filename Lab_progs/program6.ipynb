# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt1
import seaborn as sns
import string
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
# %matplotlib inline

# %%
#import the dataset
path = "./datasets/P6_P7_spam.csv"
df = pd.read_csv(path,encoding = 'latin-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df = df[['v1','v2']]
# df['length']=df['v2'].apply(len)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# remove punctuations and stopwords
def text_process(mess):
    nopunc =[char for char in mess if char not in string.punctuation]
    nopunc=''.join(nopunc)
    clean = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    if(len(clean) < 9):
        for i in range(9-len(clean)):
            clean.append(11304)
    return clean[:9]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/sujay/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df['v2'] = df['v2'].apply(text_process)
df['length'] = df['v2'].apply(len)
unique_words = []
for msg in df['v2']:
    for word in msg:
        unique_words.append(word)
unique_words = set(unique_words)
df.head()
# Out:
#      v1                                                 v2  length
# 0   ham  [Go, jurong, point, crazy, Available, bugis, n...       9
# 1   ham  [Ok, lar, Joking, wif, u, oni, 11304, 11304, 1...       9
# 2  spam  [Free, entry, 2, wkly, comp, win, FA, Cup, final]       9
# 3   ham      [U, dun, say, early, hor, U, c, already, say]       9
# 4   ham  [Nah, dont, think, goes, usf, lives, around, t...       9

# %%
len(unique_words)
# Out:
# 8508

# %%
vocab = {}
i=0
for word in unique_words:
    vocab[word]=i
    i+=1

# %%
vocab
# Out:
# {'rightly': 0,
#  'Almost': 1,
#  'cheesy': 2,
#  'X': 3,
#  'browsin': 4,
#  'sooooo': 5,
#  'created': 6,
#  'wondar': 7,
#  'officewhats': 8,
#  'envy': 9,
#  'Executive': 10,
#  'dates': 11,
#  'Mmm': 12,
#  '0796XXXXXX': 13,
#  'technical': 14,
#  'nelson': 15,
#  'Amrita': 16,
#  'PARTY': 17,
#  'welp': 18,
#  'band': 19,
#  '2U': 20,
#  '09061790126': 21,
#  'earlier': 22,
#  'Poop': 23,
#  'tis': 24,
#  'Realy': 25,
#  'Dear1': 26,
#  'dehydration': 27,
#  'jason': 28,
#  'jontin': 29,
#  'smsing': 30,
#  'deliver': 31,
#  'fixd': 32,
#  'Becomes': 33,
#  'breadstick': 34,
#  'kotees': 35,
#  'facilities': 36,
#  'freak': 37,
#  'chick': 38,
#  'visit': 39,
#  'cherish': 40,
#  'picture': 41,
#  'Bonus': 42,
#  'arab': 43,
#  'wondarfull': 44,
#  'FINE': 45,
#  'wwwcashbincouk': 46,
#  'ABTA': 47,
#  'WRONGTAKE': 48,
#  'hyde': 49,
#  'absolutely': 50,
#  'met': 51,
#  'PISS': 52,
#  'Baaaaaaaabe': 53,
#  'Shah': 54,
#  'successful': 55,
#  'Wrong': 56,
#  'Loyalty': 57,
#  'kindly': 58,
#  'recent': 59,
#  '80082': 60,
#  'sarcastic': 61,
#  '24hrs': 62,
#  '08712402972': 63,
#  'Start': 64,
#  'shanghai': 65,
#  'Auction': 66,
#  'sashimi': 67,
#  'toaday': 68,
#  'mcat': 69,
#  '09071512432': 70,
#  'wonders': 71,
#  'å£1000CALL': 72,
#  'dha': 73,
#  'latest': 74,
#  'Choose': 75,
#  'lined': 76,
#  'knowhe': 77,
#  'anderson': 78,
#  'would': 79,
#  'pm': 80,
#  'JamsterGet': 81,
#  'vehicle': 82,
#  'single': 83,
#  'detailed': 84,
#  'convincingjust': 85,
#  'lingo': 86,
#  'kg': 87,
#  'flurries': 88,
#  'Subscription': 89,
#  'significance': 90,
#  'Salad': 91,
#  'scrumptious': 92,
#  'bothering': 93,
#  'anyway': 94,
#  'CAMERA': 95,
#  'finishes': 96,
#  'Wright': 97,
#  'groovy': 98,
#  'oredi': 99,
#  '89555': 100,
#  'yellow': 101,
#  'WOULD': 102,
#  'Helen': 103,
#  'sittin': 104,
#  'items': 105,
#  'mite': 106,
#  'bcaz': 107,
#  'responsibilities': 108,
#  'easter': 109,
#  'coping': 110,
#  'U4': 111,
#  'titleso': 112,
#  'easy': 113,
#  'swt': 114,
#  'meeting': 115,
#  'th': 116,
#  'pesky': 117,
#  'leu': 118,
#  'Early': 119,
#  'gotta': 120,
#  '8am': 121,
#  'Midnight': 122,
#  'brainy': 123,
#  'stranger': 124,
#  'Ic': 125,
#  'shouldn\x89Û÷t': 126,
#  'Plyr': 127,
#  'lifeThis': 128,
#  'Unni': 129,
#  'admission': 130,
#  'kim': 131,
#  'approved': 132,
#  'appear': 133,
#  'data': 134,
#  '3miles': 135,
#  'wasnt': 136,
#  'SIB': 137,
#  'sunshine': 138,
#  'Depends': 139,
#  'semi': 140,
#  'Would': 141,
#  'Sez': 142,
#  'lyfu': 143,
#  'naughty': 144,
#  'virtual': 145,
#  'msgs': 146,
#  'despite': 147,
#  'whenever': 148,
#  'rem': 149,
#  'might': 150,
#  'l8r': 151,
#  'worryuse': 152,
#  'Shampain': 153,
#  'invention': 154,
#  'busty': 155,
#  'syllabus': 156,
#  'Wed': 157,
#  'gift': 158,
#  'IåÕm': 159,
#  'skype': 160,
#  'youdearwith': 161,
#  'XCLUSIVECLUBSAISAI': 162,
#  'mind': 163,
#  'Tension': 164,
#  'tightly': 165,
#  'openin': 166,
#  'backdoor': 167,
#  'club4mobilescom': 168,
#  'isare': 169,
#  '86888': 170,
#  'Tho': 171,
#  'church': 172,
#  '7548': 173,
#  'Sherawat': 174,
#  'Loverboy': 175,
#  'fight': 176,
#  'Mathe': 177,
#  'bowa': 178,
#  'problem': 179,
#  'privacy': 180,
#  'Vodka': 181,
#  'upping': 182,
#  'buying': 183,
#  'placement': 184,
#  'hot': 185,
#  'pases': 186,
#  'TMobile': 187,
#  'rofl': 188,
#  'Harishs': 189,
#  'remb': 190,
#  'Wats': 191,
#  '2005': 192,
#  'agree': 193,
#  'payed': 194,
#  'conveying': 195,
#  'gigolo': 196,
#  'eightish': 197,
#  'RTKIng': 198,
#  'rounderso': 199,
#  'leading': 200,
#  'processnetworking': 201,
#  'practicum': 202,
#  'T91': 203,
#  'lt': 204,
#  'trainners': 205,
#  'ArPraveesh': 206,
#  'dentist': 207,
#  'Mode': 208,
#  'shock': 209,
#  'theres': 210,
#  'female': 211,
#  'Subscriber': 212,
#  'plaza': 213,
#  'Strip': 214,
#  'hadya': 215,
#  '08707509020': 216,
#  'galcan': 217,
#  '89034': 218,
#  'waiting': 219,
#  'icicibankcom': 220,
#  'WOKE': 221,
#  'ron': 222,
#  'winds': 223,
#  'wine': 224,
#  'Shopping': 225,
#  'wanting': 226,
#  'TITLE': 227,
#  'Student': 228,
#  'Kkwhat': 229,
#  'sivatats': 230,
#  'flim': 231,
#  'contains': 232,
#  'outgoing': 233,
#  'Cup': 234,
#  'History': 235,
#  'Air': 236,
#  'aunt': 237,
#  'Carlos': 238,
#  'hoo': 239,
#  'smash': 240,
#  'Chinese': 241,
#  'blue': 242,
#  'Sppok': 243,
#  'stink': 244,
#  'Wa': 245,
#  'parts': 246,
#  'asapok': 247,
#  'embarrassed': 248,
#  'extra': 249,
#  'MECAUSE': 250,
#  'Gudnitetcpractice': 251,
#  'Beauty': 252,
#  'Bull': 253,
#  'Unlimited': 254,
#  'hisher': 255,
#  'horrible': 256,
#  'noise': 257,
#  'TEXTCOMP': 258,
#  'officer': 259,
#  'yoga': 260,
#  'sells': 261,
#  'dead': 262,
#  'addie': 263,
#  'hussey': 264,
#  'pple': 265,
#  'said': 266,
#  'sip': 267,
#  'discuss': 268,
#  'beside': 269,
#  'language': 270,
#  'Michael': 271,
#  'LUCY': 272,
#  'Ciao': 273,
#  'fink': 274,
#  'Saeed': 275,
#  'Btw': 276,
#  'often': 277,
#  'riddance': 278,
#  'ni8': 279,
#  'gas': 280,
#  'dogg': 281,
#  '85233': 282,
#  'Grumpy': 283,
#  'streetshall': 284,
#  'Rajipls': 285,
#  'å£500': 286,
#  'FREE2DAY': 287,
#  'FIFA': 288,
#  'surely': 289,
#  'Feels': 290,
#  '4GET': 291,
#  'bike': 292,
#  '4U': 293,
#  'blow': 294,
#  'Waiti': 295,
#  'Imprtant': 296,
#  'informed': 297,
#  'JJC': 298,
#  'saved': 299,
#  'juicy': 300,
#  'share': 301,
#  'Yesterday': 302,
#  'wed': 303,
#  'nachos': 304,
#  'Lul': 305,
#  '2000': 306,
#  'meis': 307,
#  'lakhs': 308,
#  'bloody': 309,
#  'somebody': 310,
#  'drvgsTo': 311,
#  'mufti': 312,
#  'thx': 313,
#  'STATION': 314,
#  'transport': 315,
#  'PORN': 316,
#  'flip': 317,
#  'doinghow': 318,
#  'Msgs': 319,
#  'ft': 320,
#  '84025': 321,
#  'resort': 322,
#  'jazz': 323,
#  'spontaneously': 324,
#  'boughtåÓbraindanceåÓa': 325,
#  'contacts': 326,
#  'Aslamalaikkuminsha': 327,
#  'KNOW': 328,
#  'side': 329,
#  'Centre': 330,
#  'EY': 331,
#  'Goodmorningmy': 332,
#  'behind': 333,
#  'learned': 334,
#  'duvet': 335,
#  'SHOP': 336,
#  'singles': 337,
#  'Package': 338,
#  'january': 339,
#  'Pink': 340,
#  'xx': 341,
#  'half': 342,
#  'jokethet': 343,
#  'URE': 344,
#  'CASH': 345,
#  'handing': 346,
#  'girl': 347,
#  'Dizzee': 348,
#  'fineabsolutly': 349,
#  'mw': 350,
#  'BACK': 351,
#  'didn\x89Û÷t': 352,
#  '50s': 353,
#  'baskets': 354,
#  'brains': 355,
#  'audition': 356,
#  'tiempo': 357,
#  'attended': 358,
#  'restrict': 359,
#  'soooo': 360,
#  'Chloe': 361,
#  'loneliness': 362,
#  'spaces': 363,
#  'sporadically': 364,
#  'accomodations': 365,
#  'adventuring': 366,
#  'andre': 367,
#  'rajas': 368,
#  'Eerie': 369,
#  'Sara': 370,
#  'membershiptake': 371,
#  '2waxsto': 372,
#  'certainly': 373,
#  '5digital': 374,
#  'clever': 375,
#  'refilled': 376,
#  'busyi': 377,
#  'ovulation': 378,
#  'gei': 379,
#  'kbut': 380,
#  'fellow': 381,
#  'olowoyey': 382,
#  'Complete': 383,
#  'caught': 384,
#  'BROTHER': 385,
#  'Welp': 386,
#  'jog': 387,
#  'bollox': 388,
#  'helens': 389,
#  'argue': 390,
#  'dnt': 391,
#  'anot': 392,
#  '09094646631': 393,
#  'Wuld': 394,
#  'DoubleTxt': 395,
#  'server': 396,
#  'claims': 397,
#  'hop': 398,
#  'Dint': 399,
#  'thangamits': 400,
#  'expression': 401,
#  'guesses': 402,
#  'smoked': 403,
#  'Europe': 404,
#  'darkness': 405,
#  'nowonion': 406,
#  'sink': 407,
#  'RECPT': 408,
#  'attracts': 409,
#  'tddnewsletteremc1couk': 410,
#  'coast': 411,
#  'Celebrated': 412,
#  'TASTS': 413,
#  'WAP': 414,
#  'cancel': 415,
#  'alian': 416,
#  'Watching': 417,
#  'Friends': 418,
#  'cashin': 419,
#  'bowls': 420,
#  'minded': 421,
#  'SPECIALE': 422,
#  'LUV': 423,
#  'sure': 424,
#  'general': 425,
#  'various': 426,
#  'wish': 427,
#  'compulsory': 428,
#  'doInterested': 429,
#  'torrents': 430,
#  'tease': 431,
#  'Yeshe': 432,
#  'emailed': 433,
#  'Goal': 434,
#  'Fair': 435,
#  'NEED': 436,
#  'isnt': 437,
#  'Parents': 438,
#  'moms': 439,
#  'hows': 440,
#  'okmail': 441,
#  'reunion': 442,
#  'know': 443,
#  'eh': 444,
#  'tariffs': 445,
#  'Joys': 446,
#  'Content': 447,
#  '25': 448,
#  '2MORO': 449,
#  'Youve': 450,
#  'canteen': 451,
#  'doesnåÕt': 452,
#  'melt': 453,
#  'last': 454,
#  'Prashanthettans': 455,
#  'NONENOWHERE': 456,
#  'dump': 457,
#  'throat': 458,
#  'hungry': 459,
#  'edward': 460,
#  'Rajnikant': 461,
#  'hen': 462,
#  'FREEFONE': 463,
#  'Bit': 464,
#  'forward': 465,
#  'bout': 466,
#  'beads': 467,
#  'stolen': 468,
#  'yun': 469,
#  '61610': 470,
#  'thirunelvali': 471,
#  'cancer': 472,
#  'fuckin': 473,
#  'Nickey': 474,
#  '447per': 475,
#  'impressed': 476,
#  'Kkwhen': 477,
#  'dis': 478,
#  'enketa': 479,
#  'noe': 480,
#  'sport': 481,
#  'School': 482,
#  '81303': 483,
#  'port': 484,
#  'literally': 485,
#  'Refused': 486,
#  'Winning': 487,
#  'å£1000': 488,
#  'don\x89Û÷t': 489,
#  'smth': 490,
#  'STARS': 491,
#  'Kyou': 492,
#  'south': 493,
#  'care': 494,
#  'morningtake': 495,
#  'deyi': 496,
#  'Virgin': 497,
#  'MobStoreQuiz10ppm': 498,
#  'Ì©': 499,
#  'heal': 500,
#  'famous': 501,
#  'Trying': 502,
#  'bright': 503,
#  'supervisor': 504,
#  'creep': 505,
#  'exactly': 506,
#  'nowcan': 507,
#  'doors': 508,
#  'shindig': 509,
#  'lover': 510,
#  'Summer': 511,
#  'decimal': 512,
#  'wwwcomuknet': 513,
#  'footy': 514,
#  'showing': 515,
#  'cover': 516,
#  'rude': 517,
#  'funny': 518,
#  'gving': 519,
#  'canada': 520,
#  'barrel': 521,
#  'shortcode': 522,
#  'Dunno': 523,
#  'goodwhen': 524,
#  'Gamestar': 525,
#  'removal': 526,
#  'self': 527,
#  'shaking': 528,
#  'numberpls': 529,
#  'POSTCARD': 530,
#  'FIELDOF': 531,
#  'year': 532,
#  'freezing': 533,
#  'Half': 534,
#  'picking': 535,
#  'melike': 536,
#  'formatting': 537,
#  'residency': 538,
#  'accept': 539,
#  'intelligent': 540,
#  'ne': 541,
#  'onto': 542,
#  'funs': 543,
#  'change': 544,
#  'Test': 545,
#  'Lmao': 546,
#  'moment': 547,
#  'sis': 548,
#  'Wifehow': 549,
#  'btwn': 550,
#  'phoned': 551,
#  '3650': 552,
#  'Doggy': 553,
#  'continent': 554,
#  'web': 555,
#  'FONE': 556,
#  '08712400200': 557,
#  'GET': 558,
#  'Baaaaabe': 559,
#  'bridge': 560,
#  'cheat': 561,
#  'gautham': 562,
#  'readiness': 563,
#  'Water': 564,
#  'lush': 565,
#  'poorly': 566,
#  'plane': 567,
#  'cancelled': 568,
#  '285': 569,
#  '24M': 570,
#  'oh': 571,
#  'fucking': 572,
#  'copy': 573,
#  'HONEYDID': 574,
#  'humans': 575,
#  'whatever': 576,
#  'ym': 577,
#  'jiayin': 578,
#  'outside': 579,
#  'shortly': 580,
#  'chart': 581,
#  'bcum': 582,
#  'Santha': 583,
#  'atyour': 584,
#  'izzit': 585,
#  'nearer': 586,
#  'captaining': 587,
#  'UCALL': 588,
#  'aspects': 589,
#  'Painful': 590,
#  'Ladies': 591,
#  'generally': 592,
#  'CaRE': 593,
#  '900': 594,
#  'Loan': 595,
#  'waheeda': 596,
#  'Audrey': 597,
#  'Luckily': 598,
#  'tomorro': 599,
#  'Check': 600,
#  'Gud': 601,
#  'sleeping': 602,
#  '449month': 603,
#  'tonight': 604,
#  'hai': 605,
#  'Golf': 606,
#  'Ho': 607,
#  'nt': 608,
#  'link': 609,
#  'temple': 610,
#  'secretary': 611,
#  'REAL': 612,
#  'spile': 613,
#  'Yavnt': 614,
#  'lasagna': 615,
#  'Customer': 616,
#  'Simply': 617,
#  'whole': 618,
#  'complacent': 619,
#  'calicut': 620,
#  'ESPECIALLY': 621,
#  'smsshsexnetUN': 622,
#  'PC': 623,
#  'carolina': 624,
#  'urgent': 625,
#  'guessing': 626,
#  'information': 627,
#  'nurses': 628,
#  'tirunelvai': 629,
#  'woah': 630,
#  'uterus': 631,
#  'accordin': 632,
#  'yeovil': 633,
#  '3MOBILE': 634,
#  'Motorola': 635,
#  'Boltblue': 636,
#  'bitch': 637,
#  'E': 638,
#  'Sir': 639,
#  '0870': 640,
#  'flight': 641,
#  'lipo': 642,
#  'breezy': 643,
#  'road': 644,
#  'Handset': 645,
#  'setting': 646,
#  'highest': 647,
#  'Mountains': 648,
#  'atlast': 649,
#  'whereare': 650,
#  'thinks': 651,
#  'temales': 652,
#  'valued': 653,
#  'accounts': 654,
#  'Sky': 655,
#  'HOME': 656,
#  'APPY': 657,
#  'lower': 658,
#  'Nojst': 659,
#  'arranging': 660,
#  'documents': 661,
#  'kalstiyathen': 662,
#  'kintu': 663,
#  '0825': 664,
#  'onwards': 665,
#  'RITE': 666,
#  'head': 667,
#  'itmay': 668,
#  'representative': 669,
#  'isComing': 670,
#  'score': 671,
#  'turning': 672,
#  'wasnåÕt': 673,
#  'successfully': 674,
#  'professional': 675,
#  'collect': 676,
#  'din': 677,
#  'Near': 678,
#  'Science': 679,
#  'Ron': 680,
#  'Kall': 681,
#  'confirmed': 682,
#  'finish': 683,
#  'Mr': 684,
#  'opened': 685,
#  'none': 686,
#  'sec': 687,
#  'enough': 688,
#  'tablets': 689,
#  'CULDNT': 690,
#  'forgiven': 691,
#  'permissions': 692,
#  'kvb': 693,
#  'plz': 694,
#  'Girl': 695,
#  'Dis': 696,
#  'matches': 697,
#  'Dan': 698,
#  'loverboy': 699,
#  'covers': 700,
#  'upgrading': 701,
#  'block': 702,
#  'angry': 703,
#  'Argument': 704,
#  'Rose': 705,
#  'ringtoneking': 706,
#  'subtoitles': 707,
#  'popped': 708,
#  'inperialmusic': 709,
#  'nan': 710,
#  'J': 711,
#  'study': 712,
#  'anonymous': 713,
#  '07815296484': 714,
#  'greatness': 715,
#  'doin': 716,
#  'Hmmmstill': 717,
#  'diddy': 718,
#  'Gettin': 719,
#  'restrictions': 720,
#  'Hiya': 721,
#  'search': 722,
#  'autocorrect': 723,
#  'txtjourney': 724,
#  'inside': 725,
#  'Bank': 726,
#  'parents': 727,
#  'finns': 728,
#  'jot': 729,
#  'ITTB': 730,
#  'hamster': 731,
#  'quit': 732,
#  'tool': 733,
#  'conclusion': 734,
#  'allowed': 735,
#  'dealer': 736,
#  'fees': 737,
#  'favorite': 738,
#  'overa': 739,
#  '400minsCall': 740,
#  'required': 741,
#  'Honestly': 742,
#  'teaches': 743,
#  'Sends': 744,
#  'paper': 745,
#  'herepls': 746,
#  'GOIN': 747,
#  'roller': 748,
#  'bomb': 749,
#  'fluids': 750,
#  'million': 751,
#  'prometazine': 752,
#  'aftr': 753,
#  'Lindsay': 754,
#  'MISSED': 755,
#  'informedRgdsRakheshKerala': 756,
#  'Germany': 757,
#  'TXTAUCTION': 758,
#  'counts': 759,
#  'John': 760,
#  'happen': 761,
#  'Free': 762,
#  'queen': 763,
#  'REGRET': 764,
#  'payback': 765,
#  'completed': 766,
#  'disappeared': 767,
#  'Eyes': 768,
#  'vl': 769,
#  '300603tcsBCM4235WC1N3XXcallcost150ppmmobilesvary': 770,
#  'Minimum': 771,
#  'å£800': 772,
#  'Luck': 773,
#  'slovely': 774,
#  'RINGTONE': 775,
#  'LONG': 776,
#  'camry': 777,
#  'Meanwhile': 778,
#  'upcharge': 779,
#  'w': 780,
#  'Indian': 781,
#  'rugby': 782,
#  'pump': 783,
#  'decided': 784,
#  'minstand': 785,
#  'salary': 786,
#  'keen': 787,
#  'entey': 788,
#  'box334sk38ch': 789,
#  'therere': 790,
#  '121': 791,
#  'Spanish': 792,
#  'morphine': 793,
#  'Win': 794,
#  'logopic': 795,
#  'measure': 796,
#  'calling': 797,
#  'ahnow': 798,
#  'finewhen': 799,
#  '448712404000Please': 800,
#  'tescos': 801,
#  'yah': 802,
#  'Com': 803,
#  'doesn\x89Û÷t': 804,
#  'collapsed': 805,
#  'Takin': 806,
#  'ph': 807,
#  'complementary': 808,
#  'flyim': 809,
#  'starts': 810,
#  'Married': 811,
#  'DAS': 812,
#  'settling': 813,
#  'Phony': 814,
#  'Shall': 815,
#  'scary': 816,
#  'tank': 817,
#  'å£400': 818,
#  'restock': 819,
#  'graphics': 820,
#  'Dick': 821,
#  'samachara': 822,
#  'route': 823,
#  'NEWQUAYSEND': 824,
#  'HARD': 825,
#  'shes': 826,
#  'stillmaybe': 827,
#  'taunton': 828,
#  'syd': 829,
#  'resuming': 830,
#  'level': 831,
#  'charming': 832,
#  'garage': 833,
#  'dayshe': 834,
#  'mom': 835,
#  'Natalie': 836,
#  'ring': 837,
#  'film': 838,
#  'slip': 839,
#  'receipts\x89ÛÓwell': 840,
#  'em': 841,
#  '0784987': 842,
#  'SEND': 843,
#  'Studying': 844,
#  'stadium': 845,
#  'youåÕre': 846,
#  'yesterday': 847,
#  'Truth': 848,
#  'future': 849,
#  'JUSWOKE': 850,
#  'sleepy': 851,
#  'Fyi': 852,
#  'Ups': 853,
#  'carly': 854,
#  'watching': 855,
#  'meDont': 856,
#  'career': 857,
#  'network': 858,
#  'rounds': 859,
#  'MOB': 860,
#  'receive': 861,
#  'oktake': 862,
#  'eviction': 863,
#  'daywith': 864,
#  'ASAP': 865,
#  'companies': 866,
#  'Orh': 867,
#  'Nohe': 868,
#  'disastrous': 869,
#  'TOBED': 870,
#  'TOWNDONTMATTER': 871,
#  'ER': 872,
#  'cn': 873,
#  'put': 874,
#  'Todaysundaysunday': 875,
#  'approaching': 876,
#  'pixels': 877,
#  'haunt': 878,
#  'gentleman': 879,
#  'treasure': 880,
#  'collected': 881,
#  'MO': 882,
#  'POKKIRI': 883,
#  'Lucky': 884,
#  'realized': 885,
#  'asia': 886,
#  'flowing': 887,
#  'bak': 888,
#  'Chikku': 889,
#  'Meds': 890,
#  '150p': 891,
#  'Euro2004': 892,
#  'CALLIN': 893,
#  'Thanku': 894,
#  'club': 895,
#  'Yeh': 896,
#  '420': 897,
#  'NRI': 898,
#  'wesley': 899,
#  'brings': 900,
#  'Dr': 901,
#  'SirSalam': 902,
#  'LIKELY': 903,
#  'Irritates': 904,
#  'digits': 905,
#  '330': 906,
#  'Whos': 907,
#  'Tiwary': 908,
#  'kz': 909,
#  'Message': 910,
#  'Rs': 911,
#  'corrct': 912,
#  'courage': 913,
#  'MojiBiola': 914,
#  'flavour': 915,
#  'rael': 916,
#  'near': 917,
#  'oblisingately': 918,
#  'cute': 919,
#  'Pie': 920,
#  'Ctter': 921,
#  'pretty': 922,
#  'railway': 923,
#  'infotxt82228couk': 924,
#  'dads': 925,
#  'way': 926,
#  'ended': 927,
#  'Sms': 928,
#  'Ive': 929,
#  'youmy': 930,
#  'Goodo': 931,
#  'admiti': 932,
#  'photos': 933,
#  'genus': 934,
#  'Tired': 935,
#  'rich': 936,
#  'unable': 937,
#  'evey': 938,
#  'Rodger': 939,
#  'spring': 940,
#  'Kusruthi': 941,
#  'processExcellent': 942,
#  'Sar': 943,
#  'RV': 944,
#  'superior': 945,
#  'useful': 946,
#  'spoke': 947,
#  'REALITY': 948,
#  'H': 949,
#  'bf': 950,
#  'Messagesome': 951,
#  'soso': 952,
#  'Thts': 953,
#  'wid': 954,
#  'dubsack': 955,
#  'harri': 956,
#  'TONESReply': 957,
#  'bring': 958,
#  'weathers': 959,
#  'En': 960,
#  '515': 961,
#  'xy': 962,
#  'posts': 963,
#  'friend': 964,
#  '1120': 965,
#  'arrive': 966,
#  'Amanda': 967,
#  'liquor': 968,
#  'flaky': 969,
#  'ashwini': 970,
#  'steamboat': 971,
#  'rub': 972,
#  'gotany': 973,
#  'ONLYFOUND': 974,
#  'expects': 975,
#  'glands': 976,
#  'Farrell': 977,
#  'hat': 978,
#  'Cttergg': 979,
#  'corvettes': 980,
#  '10am': 981,
#  'gpu': 982,
#  'emigrated': 983,
#  'cutest': 984,
#  'cooperative': 985,
#  'Mah': 986,
#  'VIOLET': 987,
#  'NAME': 988,
#  'Hint': 989,
#  'willing': 990,
#  'dearslp': 991,
#  'WISH': 992,
#  'dick': 993,
#  'fancy': 994,
#  'wk': 995,
#  'aids': 996,
#  'TOCALLSHALL': 997,
#  'diskyou': 998,
#  'mag': 999,
#  ...}

# %%
def transform_data(data_set,vocab):
    ds=[]
    for row in data_set:
        temp = []
        for word in row:
            temp.append(vocab[word])
        ds.append(temp)
    return ds

# %%
msg_train,msg_test,label_train,label_test = train_test_split(transform_data(df['v2'],vocab),df['v1'],test_size=0.2)

# %%
# improves accuracy significantly
# tfidf_transformer = TfidfTransformer(use_idf = False)
# msg_train=tfidf_transformer.transform(msg_train)
# msg_test=tfidf_transformer.transform(msg_test)
# msg_train.shape

# %%
spam_detect_model = MultinomialNB().fit(msg_train,label_train)

# %%
y_pred = spam_detect_model.predict(msg_test)
y_pred[:5]
# Out:
# array(['ham', 'ham', 'spam', 'ham', 'ham'], dtype='<U4')

# %%
print("accuracy: ",accuracy_score(label_test,y_pred))
print(classification_report(label_test,y_pred))
print(confusion_matrix(label_test,y_pred))
# Out:
# accuracy:  0.600896860986547
#               precision    recall  f1-score   support
#
#          ham       0.91      0.60      0.72       959
#         spam       0.20      0.62      0.30       156
#
#     accuracy                           0.60      1115
#    macro avg       0.55      0.61      0.51      1115
# weighted avg       0.81      0.60      0.66      1115
#
# [[573 386]
#  [ 59  97]]
